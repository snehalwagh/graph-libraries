# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %%
* item1
# Out:
#   File "<ipython-input-12-e49ce8c8869f>", line 4
# SyntaxError: can't use starred expression here

# %%
import pygal
from pygal.style import DefaultStyle
bar_chart = pygal.HorizontalBar(style=DefaultStyle, print_values=True)
bar_chart.add('IE', 19.6)
bar_chart.add('Firefox', 36.5)
